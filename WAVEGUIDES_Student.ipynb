# %% [markdown]
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/05/logo-upv-horizontal.png)
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/06/logos-perte-chip-1024x119.png)
#
#
# # Laboratory 1. Waveguides

# %% [markdown]
# Welcome to our Photonic Integrated Circuits Laboratory! Throughout the course, we will be using a Python package called [GDSFactory](https://gdsfactory.github.io/gdsfactory/index.html). This is an open-source tool, and is a great alternative to other commercial software like Synopsys Optodesigner, Luceda Photonics, or Lumerical/Interconnect. Since it runs on Python, you have two options for executing your laboratory tasks:
#
# 1. **Local installation on your own PC** (Recommended): Please note that we will not spend class time on installing the software. However, feel free to reach out if you need help with the installation.
#
# 2. **Cloud Workspace**: Alternatively, you can use a cloud-based solution if the Local installation does not work.

# %% [markdown]
# ## 0. Imports

# %% [markdown]
# For this laboratory you will need the following libraries:

# %%
import matplotlib.pyplot as plt
import numpy as np

import tidy3d as td

import gplugins as gp
import gplugins.tidy3d as gt
from gplugins import plot
from gplugins.common.config import PATH

nm = 1e-3
wavelength = np.linspace(1500, 1600,11) * nm
f = td.C_0 / wavelength

# %%
nitride_complex = td.material_library["Si3N4"]["Luke2015PMLStable"].eps_model(f)
nitride_index, nitride_k = td.Medium.eps_complex_to_nk(nitride_complex)
box_complex = td.material_library["SiO2"]["Horiba"].eps_model(f)
box_index, box_k = td.Medium.eps_complex_to_nk(box_complex)

# %% [markdown]
# ## LO.1. Effective index of a waveguide
#
# ### Convergence Tests
# We have asumed until now, that the **real** value of the effective index for each cross-section is the value provided by this mode-solver. However, this number relies on a numerical method, making it sensible to some input parameters, such as the selected grid. The objective of this section is to find the dependence of the **calculated** value of the effective index with the *grid_resolution* and the *max_grid_scaling*, the two parameters that we can modify from the automatic grid function used at the gt.modes.Waveguide() function.  <br>
# - Consider a 1.2 um width deep waveguide (SiNx), with 0.3 um height operating at 1550 nm.
#     - Sweep the *grid_resolution* between 10 and 100 in steps of 10. Plot the **calculated** effective index vs the *grid_resolution*.
#     - Select a value for the *grid_resolution* from the latter sweep (where the calculated index remains almost constant), and sweep the *max_grid_scaling* from 1.2 to 1.6 in steps of 0.1. Plot the **calculated** effective index vs the *max_grid_scaling*.
#     - Conclude which will be the best configuration for the grid parameters for this particular case.

# %%
deep_waveguide = gt.modes.Waveguide(
    # Geometrical Parameters
    core_width=1.2, # Waveguide width
    core_thickness=300 * nm, # Waveguide height 
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=1550 * nm, # Wavelength to simulate
    num_modes=4, # Targeted number of modes to find 
    max_grid_scaling=1.5, # Parameters of the grid 
    grid_resolution=20, # Parameters of the grid
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
)

deep_waveguide.plot_index()

# %%
# Student continue your code here ...

grid_resolution = np.linspace(10,100,10)
res_neff = []

for i in range(10): 
    deep_waveguide = gt.modes.Waveguide(
        # Geometrical Parameters
        core_width=1.2, # Waveguide width
        core_thickness=300 * nm, # Waveguide height 
        slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
        # Materials
        core_material='sin', #  Material of the waveguide
        clad_material='sio2', # Surrounding material
        # Modesolver Parameters
        wavelength=1550 * nm, # Wavelength to simulate
        num_modes=1, # Targeted number of modes to find 
        max_grid_scaling=1.5, # Parameters of the grid 
        grid_resolution= grid_resolution[i], # Parameters of the grid
        cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
        precision='double',
    )

    n_eff= deep_waveguide.n_eff.real
    res_neff.append(n_eff)

res_neff=np.array(res_neff)

plt.figure(figsize=(10, 5))
plt.title(f"Grid resolution vs n_eff")
plt.xlabel("Grid resolution")
plt.ylabel("neff")
plt.grid()
plt.plot(grid_resolution, res_neff)
# Out:
# 2026-02-16 13:29:13.453 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_09770a5eb4303d37.npz.
# 2026-02-16 13:29:13.575 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_972b4c36731994ce.npz.
# 2026-02-16 13:29:13.577 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_4aa1037aeb7bae0f.npz.
# 2026-02-16 13:29:13.581 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_4a7cfe924ea84b0e.npz.
# 2026-02-16 13:29:13.587 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a75f11ee34197d65.npz.
# 2026-02-16 13:29:13.595 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_9f3aaac580067da9.npz.
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:29:53 CET WARNING: The group index was not computed. To calculate group
#              index, pass 'group_index_step = True' in the 'ModeSpec'.
# 2026-02-16 13:29:53.631 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_a122f2de27436370.npz.
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-02-16 13:30:39.246 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_55052adad499f4e5.npz.
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-02-16 13:31:11.703 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_3f00d13b3ed47c23.npz.
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-02-16 13:31:45.606 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_734506418d905a04.npz.

# %%
max_grid_scaling = np.linspace(1.2,1.6,5)
res_neff = []

for i in range(5): 
    deep_waveguide = gt.modes.Waveguide(
        # Geometrical Parameters
        core_width=1.2, # Waveguide width
        core_thickness=300 * nm, # Waveguide height 
        slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
        # Materials
        core_material='sin', #  Material of the waveguide
        clad_material='sio2', # Surrounding material
        # Modesolver Parameters
        wavelength=1550 * nm, # Wavelength to simulate
        num_modes=4, # Targeted number of modes to find 
        max_grid_scaling= max_grid_scaling[i], # Parameters of the grid 
        grid_resolution= 20, # Parameters of the grid
        cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
        precision='double',
    )

    n_eff= deep_waveguide.n_eff[0].real
    res_neff.append(n_eff)

res_neff = np.array(res_neff)

plt.figure(figsize=(10, 5))
plt.title(f"Max grid scaling vs n_eff")
plt.xlabel("Max grid scaling")
plt.ylabel("neff")
plt.grid()
plt.plot(max_grid_scaling, res_neff)
# Out:
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:32:09 CET WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:32:09.117 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_29761b037c0c9026.npz.
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:32:11 CET WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:32:11.496 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_fbe312fd02002ae4.npz.
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:32:14 CET WARNING: Mode field at frequency index 0, mode index 2 does not
#              decay at the plane boundaries.
# 13:32:15 CET WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:32:15.172 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_76e2764f504071ba.npz.
# 2026-02-16 13:32:15.474 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_cf92515ae4232c65.npz.
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/maria_romero/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:32:18 CET WARNING: Mode field at frequency index 0, mode index 2 does not
#              decay at the plane boundaries.
#              WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:32:19.114 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_683206c3f01233c4.npz.

# %% [markdown]
# ## LO.2. Width dependence

# %% [markdown]
# - Perform a sweep of the **deep** waveguide width. Use the code provided in the following cell or program your own sweep.

# %%
wavelength = 1.55 # Student code here

deep_waveguide = gt.modes.Waveguide(
    wavelength=wavelength,
    core_width=1.2,
    core_material='sin',
    clad_material='sio2',
    core_thickness=300 * nm,
    slab_thickness=0 * nm,
    num_modes=4,
    cache_path='.cache/',
    precision='double',
    max_grid_scaling=1.2,
    grid_resolution=20, 
)

w = np.linspace(0.6,1.6,11) # Student code here

sweep_neff = gt.modes.sweep_n_eff(deep_waveguide, 
                             core_width=w)

sweep_tefraction = gt.modes.sweep_fraction_te(deep_waveguide,
                                              core_width=w)

plt.figure(figsize=(10, 5))
for k in range(sweep_neff.shape[1]):
    plt.scatter(w, sweep_neff[:,k].real,edgecolors='k',c=sweep_tefraction.sel(mode_index=k),vmin=0, vmax=1,label = '__nolegend__',cmap='bwr')
    plt.plot(w, sweep_neff[:,k].real,label=f'Mode {k}')

plt.title("Deep waveguide width sweep - 1550nm")
plt.xlabel("Width (um)")
plt.ylabel("neff")
plt.grid()
plt.hlines(np.mean(box_index), xmin=np.min(w), xmax=np.max(w), colors='k', linestyles='dashed',label='SiO2 index')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout(rect=[0, 0, 0.85, 1])
plt.colorbar(orientation='horizontal',fraction=0.04).set_label("TE fraction")
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 17:11:50 Hora estándar romance WARNING: Mode field at frequency index 0, mode
#                                index 2 does not decay at the plane boundaries.
#                                WARNING: Mode field at frequency index 0, mode
#                                index 3 does not decay at the plane boundaries.
#                                WARNING: The group index was not computed. To
#                                calculate group index, pass 'group_index_step =
#                                True' in the 'ModeSpec'.
# 2026-02-16 17:11:50.450 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache\Waveguide_e0f2a62752cad497.npz.
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 17:11:51 Hora estándar romance WARNING: Mode field at frequency index 0, mode
#                                index 2 does not decay at the plane boundaries.
#                                WARNING: Mode field at frequency index 0, mode
#                                index 3 does not decay at the plane boundaries.
# 2026-02-16 17:11:51.554 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache\Waveguide_cad20f99025f789a.npz.
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 17:11:52 Hora estándar romance WARNING: Mode field at frequency index 0, mode
#                                index 2 does not decay at the plane boundaries.
#                                WARNING: Mode field at frequency index 0, mode
#                                index 3 does not decay at the plane boundaries.
# 2026-02-16 17:11:52.714 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache\Waveguide_575965d134f345c4.npz.
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 17:11:53 Hora estándar romance WARNING: Mode field at frequency index 0, mode
#                                index 2 does not decay at the plane boundaries.
#                                WARNING: Mode field at frequency index 0, mode
#                                index 3 does not decay at the plane boundaries.
# 2026-02-16 17:11:53.853 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache\Waveguide_3ca61e62fe85ccf2.npz.
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 17:11:55 Hora estándar romance WARNING: Mode field at frequency index 0, mode
#                                index 2 does not decay at the plane boundaries.
#                                WARNING: Mode field at frequency index 0, mode
#                                index 3 does not decay at the plane boundaries.
# 2026-02-16 17:11:55.138 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache\Waveguide_8b617c8aef408673.npz.
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 17:11:56 Hora estándar romance WARNING: Mode field at frequency index 0, mode
#                                index 2 does not decay at the plane boundaries.
#                                WARNING: Mode field at frequency index 0, mode
#                                index 3 does not decay at the plane boundaries.
# 2026-02-16 17:11:56.336 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache\Waveguide_cd84020834745298.npz.
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 17:11:57 Hora estándar romance WARNING: Mode field at frequency index 0, mode
#                                index 3 does not decay at the plane boundaries.
# 2026-02-16 17:11:57.676 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache\Waveguide_df7667b1ace5cc7e.npz.
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-02-16 17:11:58.938 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache\Waveguide_a4e198a34f8f1987.npz.
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-02-16 17:12:00.301 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache\Waveguide_1cba93ec3f707c97.npz.
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-02-16 17:12:01.418 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache\Waveguide_495965be167ef02f.npz.
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-02-16 17:12:02.644 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache\Waveguide_415c86fe948629a6.npz.
#   0%|          | 0/11 [00:00<?, ?it/s]
# 2026-02-16 17:12:02.665 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_e0f2a62752cad497.npz.
# 2026-02-16 17:12:02.708 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_cad20f99025f789a.npz.
# 2026-02-16 17:12:02.742 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_575965d134f345c4.npz.
# 2026-02-16 17:12:02.782 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_3ca61e62fe85ccf2.npz.
# 2026-02-16 17:12:02.811 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_8b617c8aef408673.npz.
# 2026-02-16 17:12:02.837 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_cd84020834745298.npz.
# 2026-02-16 17:12:02.861 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_df7667b1ace5cc7e.npz.
# 2026-02-16 17:12:02.886 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_a4e198a34f8f1987.npz.
# 2026-02-16 17:12:02.913 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_1cba93ec3f707c97.npz.
# 2026-02-16 17:12:02.940 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_495965be167ef02f.npz.
# 2026-02-16 17:12:02.964 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_415c86fe948629a6.npz.

# %% [markdown]
# ## LO.3. Waveguide compact model

# %% [markdown]
# A compact model of an integrated photonic waveguide is a reduced-order mathematical model that describes the waveguide’s optical behavior—such as phase propagation, loss, and dispersion, using analytical or semi-analytical equations. Consider:

# %% [markdown]
# Transfer function for propagation in a waveguide:
#
# $$
# H(\lambda)
# = e^{-j\,\beta(\lambda)\,z}
# = e^{-j\,\mathrm{Re}\{\beta(\lambda)\}\,z}\,
#   e^{\mathrm{Im}\{\beta(\lambda)\}\,z}.
# $$
#
# Where
#
# $$
# \beta(\lambda)
# = \frac{2\pi}{\lambda}\,\mathrm{Re}\{n_\mathrm{eff}(\lambda)\}.
# $$
#
# Let's model the waveguide's effective index wavelength variation using a second order polynomial:
#
# $$
# n_\mathrm{eff}(\lambda)
# = n_{1} + n_{2}\,(\lambda-\lambda_{0}) + n_{3}\,(\lambda-\lambda_{0})^{2}
# $$
#
# Where
#
# 1.
# $$
# n_\mathrm{eff}(\lambda_0) = n_1
# $$
# 2.
# $$
# n_g(\lambda_0) = n_1 - n_2\,\lambda_0
# $$
# 3.
# $$
# D = -\frac{2\,\lambda_0\,n_3}{c}\;\;[\mathrm{s}^2/\mathrm{m}]
# $$
#
# - Find the **compact models** of the following waveguides:
#     - Deep waveguide, height = 300nm, width = 1.2um
#     - Shallow waveguide, core height = 300nm, slab height = 150 nm, width = 1.2um
#
# **TIP**. Use the Lab0.1.Modesolver results (neff vs lambda) as starting point. Fit the results using a second order polynomial (with the lambda_0 shift) and relate the fit results to n_g and D values.

# %% [markdown]
# Deep waveguide:

# %%
# STUDENT! Put your code here.
wavelength = np.linspace(1.5, 1.6, 11)  # Student code here. Tip np.linspace()
lambda_0 = 1.55
desplazamiento = wavelength - lambda_0
c = 3e8

deep_waveguide = gt.modes.Waveguide(
    wavelength=wavelength, 
    core_width=1.2, 
    slab_thickness= 0,
    core_material='sin',
    clad_material='sio2',
    core_thickness=300 * nm,
    num_modes=2,
    cache_path='.cache/',
    precision='double',
    max_grid_scaling=1.5,
    grid_resolution=20, 
)

res_neff = deep_waveguide.n_eff # In this case, the result is not just a number, is a wavelength-dependent vector

plt.figure(figsize=(10,5))
for k in range(res_neff.shape[1]):
    coefficients= np.polyfit(desplazamiento, res_neff[:,k].real, 2)
    n3 = coefficients[0]
    n2 = coefficients[1]
    n1 = coefficients[2]
    p = np.poly1d(coefficients)
    plt.scatter(wavelength, res_neff[:,k].real,edgecolors='k',facecolors='none',label = f'Data mode {k}')
    plt.plot(wavelength, res_neff[:,k].real,'-', label = f'Polynomial fit mode {k}')
    neff_lambda0 = n1
    ng_lambda_0 = n1 - n2 * lambda_0
    D = -(2*lambda_0*1e-6*n3)/c
    print(f"\n--- MODO {k}-----")
    print(f" n1 = {n1}")
    print(f" n2 = {n2}")
    print(f" n3 = {n3}")
    print(f" neff_lambda0 = {neff_lambda0}")
    print(f" ng_lambda_0 = {ng_lambda_0}")
    print(f" D = {D} [s^2/m]")

plt.title(f"Compact model: deep waveguide")
plt.xlabel("Wavelength (um)")
plt.ylabel("neff")
plt.grid()
plt.legend()
plt.show()
# Out:
# 2026-02-16 18:05:35.627 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_30d1ee08cd46db1e.npz.
# --- MODO 0-----
#  n1 = 1.6047340632190406
#  n2 = -0.21577677458043676
#  n3 = 0.09712502177697745
#  neff_lambda0 = 1.6047340632190406
#  ng_lambda_0 = 1.9391880638187176
#  D = -1.003625225028767e-15 [s^2/m]
#
# --- MODO 1-----
#  n1 = 1.5273801082613834
#  n2 = -0.15850398269730642
#  n3 = 0.15453139703774948
#  neff_lambda0 = 1.5273801082613834
#  ng_lambda_0 = 1.7730612814422084
#  D = -1.5968244360567444e-15 [s^2/m]

# %% [markdown]
# Shallow waveguide:

# %%
# STUDENT! Put your code here.
wavelength = np.linspace(1.5, 1.6, 11)  # Student code here. Tip np.linspace()
lambda_0 = 1.55
desplazamiento = wavelength - lambda_0
c = 3e8

deep_waveguide = gt.modes.Waveguide(
    wavelength=wavelength, 
    core_width=1.2, 
    slab_thickness= 150*nm,
    core_material='sin',
    clad_material='sio2',
    core_thickness=300 * nm,
    num_modes=2,
    cache_path='.cache/',
    precision='double',
    max_grid_scaling=1.5,
    grid_resolution=20, 
)

res_neff = deep_waveguide.n_eff # In this case, the result is not just a number, is a wavelength-dependent vector

plt.figure(figsize=(10,5))
for k in range(res_neff.shape[1]):
    coefficients= np.polyfit(desplazamiento, res_neff[:,k].real, 2)
    n3 = coefficients[0]
    n2 = coefficients[1]
    n1 = coefficients[2]
    p = np.poly1d(coefficients)
    plt.scatter(wavelength, res_neff[:,k].real,edgecolors='k',facecolors='none',label = f'Data mode {k}')
    plt.plot(wavelength, res_neff[:,k].real, '-', label = f'Polynomial fit mode {k}')
    neff_lambda0 = n1
    ng_lambda_0 = n1 - n2 * lambda_0
    D = -(2*lambda_0*1e-6*n3)/c
    print(f"\n--- MODO {k}-----")
    print(f" n1 = {n1}")
    print(f" n2 = {n2}")
    print(f" n3 = {n3}")
    print(f" neff_lambda0 = {neff_lambda0}")
    print(f" ng_lambda_0 = {ng_lambda_0}")
    print(f" D = {D} [s^2/m]")

plt.title(f"Compact model: shallow waveguide")
plt.xlabel("Wavelength (um)")
plt.ylabel("neff")
plt.grid()
plt.legend()
plt.show
# Out:
# 2026-02-16 18:06:00.975 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_542e1d928caca95b.npz.
#
# --- MODO 0-----
#  n1 = 1.6195105801340899
#  n2 = -0.18744906474109688
#  n3 = 0.09761939843254601
#  neff_lambda0 = 1.6195105801340899
#  ng_lambda_0 = 1.91005663048279
#  D = -1.0087337838029754e-15 [s^2/m]
#
# --- MODO 1-----
#  n1 = 1.5386466192156631
#  n2 = -0.14095813259648168
#  n3 = 0.15965233141379237
#  neff_lambda0 = 1.5386466192156631
#  ng_lambda_0 = 1.7571317247402098
#  D = -1.6497407579425213e-15 [s^2/m]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## LO.4. Bend waveguide radius vs. loss – deep

# %% [markdown]
# The bend loss has three primary contributions:
#
# 1. Mode-mismatch loss
# 2. Radiation loss
# 3. Propagation loss

# %%
bend_1550 = gt.modes.Waveguide(
    wavelength=1550 * nm,
    core_width=1.2,
    slab_thickness=0.0,
    core_material='sin',
    clad_material='sio2',
    core_thickness=300 * nm,
    num_modes=1,
    cache_path='.cache/',
    precision='double',
    max_grid_scaling=1.2,
    grid_resolution=30, 
    bend_radius=20, # Bend radius
)

bend_1550.plot_field(field_name="Ex", 
                     mode_index=0, # Field to be plotted
                     value='real', # Real - abs - imag
                     cmap='coolwarm',
                     xlim=(-1.5, 1.5), # Set the x and y limits
                     ylim=(-0.7, 1))
# Out:
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-02-16 18:18:30.559 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache\Waveguide_1592dba1d8e935a8.npz.

# %% [markdown]
# ### Mode-mismatch loss
#
# Bend waveguide mode differs slightly from the straight waveguide mode, wich yield into mode-convertion losses. We can calculate this factor with as the overlap of the latter two modes.
#
# This is already implemented on GDSfactory library:

# %%
radii = np.arange(20.0, 120,11)

mismatch = gt.modes.sweep_bend_mismatch(bend_1550, radii)

plt.plot(radii, 10 * np.log10(mismatch))
plt.title("Strip waveguide bend")
plt.xlabel("Radius (μm)")
plt.ylabel("Mismatch (dB)")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# Text(0, 0.5, 'Mismatch (dB)')

# %% [markdown]
# ### Propagation loss
#
# Consider the equivalent linear length of the quarter-circle bend. Light will attenuate following a trend quantified with the experimentally measured parameter $$\alpha [\mathrm{dB}/\mathrm{cm}]$$. It depends on the fabrication process mainly. We will add this loss (in dBs) to the mode-mismatch loss to calculate the total loss per bend.
#
# *We are not considering the radiation losses, mainly because is not easy to implement a quick simulation for this parameter. Under certain conditions, the main loss sources are the ones considered in this example

# %%
dB_cm = 1.5  # dB/cm Technology loss - 
length = 0.5 * np.pi * radii * 1e-6
propagation_loss = dB_cm * length * 1e2
propagation_loss

plt.title("Bend loss for TE polarization")
plt.plot(radii, -10 * np.log10(mismatch), ".", label="Mode loss")
plt.plot(radii, propagation_loss, ".", label="Propagation loss")
plt.plot(radii, propagation_loss-10 * np.log10(mismatch), "-o", label="Total loss")
plt.xlabel("Bend radius (um)")
plt.ylabel("Loss (dB)")
plt.legend()

# %% [markdown]
# - Use the code provided in this section to calculate the safe radius for 1.2 um width deep waveguides at 1.5 um.

# %%
bend_radius = np.linspace(25, 150, 6)
res_neff_te = []
res_neff_tm = []

for i in range(6):
    deep_waveguide = gt.modes.Waveguide(
            # Geometrical Parameters
            core_width=1, # Waveguide width
            core_thickness=300 * nm, # Waveguide height 
            slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
            # Materials
            core_material='sin', #  Material of the waveguide
            clad_material='sio2', # Surrounding material
            # Modesolver Parameters
            wavelength=1.5, # Wavelength to simulate
            num_modes=2, # Targeted number of modes to find 
            max_grid_scaling= 1.55, # Parameters of the grid 
            grid_resolution= 20, # Parameters of the grid
            cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
            precision='double',
            bend_radius = bend_radius[i]
    )
        
    n_te = np.real(deep_waveguide.n_eff[0])
    n_tm = np.real(deep_waveguide.n_eff[1])
    
    res_neff_te.append(n_te)
    res_neff_tm.append(n_tm)


plt.plot(bend_radius,res_neff_te, label = "TE mode")
plt.plot(bend_radius,res_neff_tm, label = "TM mode")
plt.xlabel("bend radius (um)")
plt.ylabel("neff")
plt.legend()
plt.grid()
plt.title(" neff vs Bend Radius")
# Out:
# 2026-03-05 21:04:16.465 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_9462f4adb821997b.npz.
# 2026-03-05 21:04:16.470 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_91eb49fc3468578f.npz.
# 2026-03-05 21:04:16.474 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_9ef58d2875d0a778.npz.
# 2026-03-05 21:04:16.479 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_5976ac4f7f288c0f.npz.
# 2026-03-05 21:04:16.484 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_bcdd43fe8566b173.npz.
# 2026-03-05 21:04:16.491 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_b0b09bb6967d5d00.npz.
# Text(0.5, 1.0, ' neff vs Bend Radius')

# %%
bend_radius = np.linspace(25, 150, 6)
res_neff = []


for i in range(6):
    deep_waveguide = gt.modes.Waveguide(
            # Geometrical Parameters
            core_width=1, # Waveguide width
            core_thickness=300 * nm, # Waveguide height 
            slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
            # Materials
            core_material='sin', #  Material of the waveguide
            clad_material='sio2', # Surrounding material
            # Modesolver Parameters
            wavelength=1.5, # Wavelength to simulate
            num_modes=2, # Targeted number of modes to find 
            max_grid_scaling= 1.55, # Parameters of the grid 
            grid_resolution= 20, # Parameters of the grid
            cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
            precision='double',
            bend_radius = bend_radius[i]
    )
    
    res_neff.append(deep_waveguide.n_eff.real)

res_neff = np.array(res_neff)
plt.plot(bend_radius,res_neff[:,0], label = "TE mode")
plt.xlabel("bend radius (um)")
plt.ylabel("neff")
plt.legend()
plt.grid()
plt.title("neff vs Bend Radius")
# Out:
# 2026-03-05 21:06:31.577 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_9462f4adb821997b.npz.
# 2026-03-05 21:06:31.583 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_91eb49fc3468578f.npz.
# 2026-03-05 21:06:31.586 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_9ef58d2875d0a778.npz.
# 2026-03-05 21:06:31.590 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_5976ac4f7f288c0f.npz.
# 2026-03-05 21:06:31.594 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_bcdd43fe8566b173.npz.
# 2026-03-05 21:06:31.598 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_b0b09bb6967d5d00.npz.
# Text(0.5, 1.0, 'neff vs Bend Radius')

# %%
te_wvg = gt.modes.Waveguide(
    wavelength=1550 * nm, 
    core_width=1.0,       
    slab_thickness=0.0,
    core_material='sin',
    clad_material='sio2',
    core_thickness=300 * nm,
    num_modes=1,
    cache_path='.cache/',
    precision='double',
    max_grid_scaling=1.2,
    grid_resolution=30, 
)



mismatch_loss = gt.modes.sweep_bend_mismatch(te_wvg, bend_radius)
mismatch_loss_dB = -10 * np.log10(mismatch_loss) 
dB_cm = 1.5 
length_cm = 0.5 * np.pi * bend_radius * 1e-4
prop_loss_dB = dB_cm * length_cm
total_loss_dB = mismatch_loss_dB + prop_loss_dB

plt.figure(figsize=(8,5))
plt.title("Loss TE (Width 1.0 um)")
plt.plot(bend_radius, mismatch_loss_dB, "o-", label="Mode mismatch loss")
plt.plot(bend_radius, prop_loss_dB, "o-", label="Propagation loss")
plt.plot(bend_radius, total_loss_dB, "o-", label="Total loss")
plt.xlabel("Bend radius (um)")
plt.ylabel("Loss (dB/90º)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))

# %% [markdown]
# ## EXTRA
#
# All the past simulations were done considering as core material de Silicon Nitride (SiNx) and Silicon Dioxide (SiO2) as cladding material. Now, **simulate the Silicon-On-Insulator technology changing the core material to Silicon (Si)**. In this case, the dimensions will be 220 nm heigth and 500 nm width.
# 1. Repeat the LO.1. wavelength behavior simulations, considering the updated materials and dimensions.
# 2. Repeat the LO.3. width dependence analysis, now sweeping in a 300nm - 1um range.
# 3. Find the safe radius for this technology. Consider sweeping the radius in a 5um to 30um range.
# 4. **Compare the SiNx and SOI technologies**

# %% [markdown]
# # LO1: SOI

# %%
grid_resolution = np.linspace(10,100,10)
res_neff = []

for i in range(10): 
    deep_waveguide = gt.modes.Waveguide(
        # Geometrical Parameters
        core_width= 500*nm, # Waveguide width
        core_thickness=220 * nm, # Waveguide height 
        slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
        # Materials
        core_material='si', #  Material of the waveguide
        clad_material='sio2', # Surrounding material
        # Modesolver Parameters
        wavelength=1550 * nm, # Wavelength to simulate
        num_modes=1, # Targeted number of modes to find 
        max_grid_scaling=1.5, # Parameters of the grid 
        grid_resolution= grid_resolution[i], # Parameters of the grid
        cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
        precision='double',
    )

    n_eff= deep_waveguide.n_eff.real
    res_neff.append(n_eff)

res_neff=np.array(res_neff)

plt.figure(figsize=(10, 5))
plt.title(f"Grid resolution vs n_eff: SOI")
plt.xlabel("Grid resolution")
plt.ylabel("neff")
plt.grid()
plt.plot(grid_resolution, res_neff)
# Out:
# 2026-03-05 19:59:04.405 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_4a1d722b79a898fe.npz.
# 2026-03-05 19:59:04.418 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_03f4f47742c6dd39.npz.
# 2026-03-05 19:59:04.423 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_df6b8c7ded5c819f.npz.
# 2026-03-05 19:59:04.427 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_e180c41701f0a45c.npz.
# 2026-03-05 19:59:04.430 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_99c2a1f132c5aa29.npz.
# 2026-03-05 19:59:04.435 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_376ad1e6757d68e9.npz.
# 2026-03-05 19:59:04.443 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_d39692b947d95237.npz.
# 2026-03-05 19:59:04.449 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_778e926092e76bcf.npz.
# 2026-03-05 19:59:04.455 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_2c91b2b2c10ec371.npz.
# 2026-03-05 19:59:04.458 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_db7d01ebc114c07f.npz.

# %%
max_grid_scaling = np.linspace(1.2,1.6,5)
res_neff = []

for i in range(5): 
    deep_waveguide = gt.modes.Waveguide(
        # Geometrical Parameters
        core_width=500*nm, # Waveguide width
        core_thickness=220 * nm, # Waveguide height 
        slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
        # Materials
        core_material='si', #  Material of the waveguide
        clad_material='sio2', # Surrounding material
        # Modesolver Parameters
        wavelength=1550 * nm, # Wavelength to simulate
        num_modes=4, # Targeted number of modes to find 
        max_grid_scaling= max_grid_scaling[i], # Parameters of the grid 
        grid_resolution= 20, # Parameters of the grid
        cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
        precision='double',
    )

    n_eff= deep_waveguide.n_eff[0].real
    res_neff.append(n_eff)

res_neff = np.array(res_neff)

plt.figure(figsize=(10, 5))
plt.title(f"Max grid scaling vs n_eff: SOI")
plt.xlabel("Max grid scaling")
plt.ylabel("neff")
plt.grid()
plt.plot(max_grid_scaling, res_neff)
# Out:
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 20:03:01 Hora estándar romance WARNING: Mode field at frequency index 0, mode
#                                index 3 does not decay at the plane boundaries.
# 2026-03-05 20:03:01.855 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache\Waveguide_223d93916735b32f.npz.
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 20:03:03 Hora estándar romance WARNING: Mode field at frequency index 0, mode
#                                index 3 does not decay at the plane boundaries.
# 2026-03-05 20:03:03.477 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache\Waveguide_2b23fbc3e6bc4a22.npz.
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 20:03:04 Hora estándar romance WARNING: Mode field at frequency index 0, mode
#                                index 3 does not decay at the plane boundaries.
# 2026-03-05 20:03:04.774 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache\Waveguide_d2a12d2520042e19.npz.
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 20:03:06 Hora estándar romance WARNING: Mode field at frequency index 0, mode
#                                index 3 does not decay at the plane boundaries.
# 2026-03-05 20:03:06.060 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache\Waveguide_9b607c2ee0ef414d.npz.
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 20:03:07 Hora estándar romance WARNING: Mode field at frequency index 0, mode
#                                index 3 does not decay at the plane boundaries.
# 2026-03-05 20:03:07.742 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache\Waveguide_02d6f234e1cf89a5.npz.

# %% [markdown]
# ## LO2: SOI

# %%
wavelength = 1.55 # Student code here

deep_waveguide = gt.modes.Waveguide(
    wavelength=wavelength,
    core_width=500*nm,
    core_material='si',
    clad_material='sio2',
    core_thickness=220 * nm,
    slab_thickness=0 * nm,
    num_modes=4,
    cache_path='.cache/',
    precision='double',
    max_grid_scaling=1.3,
    grid_resolution=20, 
)

w = np.linspace(0.3,1,8) # Student code here

sweep_neff = gt.modes.sweep_n_eff(deep_waveguide, 
                             core_width=w)

sweep_tefraction = gt.modes.sweep_fraction_te(deep_waveguide,
                                              core_width=w)

plt.figure(figsize=(10, 5))
for k in range(sweep_neff.shape[1]):
    plt.scatter(w, sweep_neff[:,k].real,edgecolors='k',c=sweep_tefraction.sel(mode_index=k),vmin=0, vmax=1,label = '__nolegend__',cmap='bwr')
    plt.plot(w, sweep_neff[:,k].real,label=f'Mode {k}')

plt.title("Deep waveguide width sweep - 1550nm : SOI")
plt.xlabel("Width (um)")
plt.ylabel("neff")
plt.grid()
plt.hlines(np.mean(box_index), xmin=np.min(w), xmax=np.max(w), colors='k', linestyles='dashed',label='SiO2 index')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout(rect=[0, 0, 0.85, 1])
plt.colorbar(orientation='horizontal',fraction=0.04).set_label("TE fraction")
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# 2026-03-05 20:15:25.415 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_9fd1473f015a7c34.npz.
# 2026-03-05 20:15:25.419 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_de4256b39f9e99bc.npz.
# 2026-03-05 20:15:25.422 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_2b23fbc3e6bc4a22.npz.
# 2026-03-05 20:15:25.426 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_b975db0abae852bd.npz.
# 2026-03-05 20:15:25.430 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_4723c77520ee8c07.npz.
# 2026-03-05 20:15:25.434 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_c5bb96a0217067c4.npz.
# 2026-03-05 20:15:25.438 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_06d152db8d9e0430.npz.
# 2026-03-05 20:15:25.441 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_365f38b8c3e3b36e.npz.
#   0%|          | 0/8 [00:00<?, ?it/s]
# 2026-03-05 20:15:25.462 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_9fd1473f015a7c34.npz.
# 2026-03-05 20:15:25.467 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_de4256b39f9e99bc.npz.
# 2026-03-05 20:15:25.471 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_2b23fbc3e6bc4a22.npz.
# 2026-03-05 20:15:25.474 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_b975db0abae852bd.npz.
# 2026-03-05 20:15:25.480 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_4723c77520ee8c07.npz.
# 2026-03-05 20:15:25.485 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_c5bb96a0217067c4.npz.
# 2026-03-05 20:15:25.489 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_06d152db8d9e0430.npz.
# 2026-03-05 20:15:25.494 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_365f38b8c3e3b36e.npz.

# %% [markdown]
# ## SAFE RADIUS: SOI

# %%
bend_radius = np.linspace(5,30,6)
res_neff_te = []
res_neff_tm = []

for i in range(6): 
    deep_waveguide = gt.modes.Waveguide(
            # Geometrical Parameters
            core_width= 500*nm, 
            core_thickness=220 * nm, # Waveguide height 
            slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
            # Materials
            core_material='si', #  Material of the waveguide
            clad_material='sio2', # Surrounding material
            # Modesolver Parameters
            wavelength=1550*nm, # Wavelength to simulate
            num_modes=2, # Targeted number of modes to find 
            max_grid_scaling= 1.3, # Parameters of the grid 
            grid_resolution= 50, # Parameters of the grid
            cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
            precision='double',
            bend_radius = bend_radius[i]
    )

    n_te = np.real(deep_waveguide.n_eff[0])
    n_tm = np.real(deep_waveguide.n_eff[1])
    
    res_neff_te.append(n_te)
    res_neff_tm.append(n_tm)

#res_neff = np.array(res_neff)
plt.plot(bend_radius,res_neff_te, label = "TE mode")
plt.plot(bend_radius,res_neff_tm, label = "TM mode")
plt.xlabel("bend radius (um)")
plt.ylabel("neff")
plt.legend()
plt.grid()
plt.title(" neff vs Bend Radius (SOI)")
# Out:
# 2026-03-05 21:08:36.844 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_e5b8dfdd55fadae6.npz.
# 2026-03-05 21:08:36.849 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_4eb2cc450f10469d.npz.
# 2026-03-05 21:08:36.855 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_1519d8f9386d4496.npz.
# 2026-03-05 21:08:36.861 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_a7f9ba355fb83657.npz.
# 2026-03-05 21:08:36.865 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_4f9ccdab3d26e38f.npz.
# 2026-03-05 21:08:36.870 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_5fc1f3d9c4efbed0.npz.
# Text(0.5, 1.0, ' neff vs Bend Radius (SOI)')

# %%
bend_radius = np.linspace(5,30,6)
res_neff = []

for i in range(6): 
    deep_waveguide = gt.modes.Waveguide(
            # Geometrical Parameters
            core_width= 500*nm, 
            core_thickness=220 * nm, # Waveguide height 
            slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
            # Materials
            core_material='si', #  Material of the waveguide
            clad_material='sio2', # Surrounding material
            # Modesolver Parameters
            wavelength=1550*nm, # Wavelength to simulate
            num_modes=2, # Targeted number of modes to find 
            max_grid_scaling= 1.3, # Parameters of the grid 
            grid_resolution= 50, # Parameters of the grid
            cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
            precision='double',
            bend_radius = bend_radius[i]
        )
    res_neff.append(deep_waveguide.n_eff.real)

res_neff = np.array(res_neff)
plt.plot(bend_radius,res_neff[:,0], label = "TE mode")
plt.xlabel("bend radius (um)")
plt.ylabel("neff")
plt.legend()
plt.grid()
plt.title("neff vs Bend Radius: TE (SOI)")
# Out:
# 2026-03-05 21:09:10.872 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_e5b8dfdd55fadae6.npz.
# 2026-03-05 21:09:10.877 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_4eb2cc450f10469d.npz.
# 2026-03-05 21:09:10.880 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_1519d8f9386d4496.npz.
# 2026-03-05 21:09:10.885 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_a7f9ba355fb83657.npz.
# 2026-03-05 21:09:10.890 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_4f9ccdab3d26e38f.npz.
# 2026-03-05 21:09:10.894 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache\Waveguide_5fc1f3d9c4efbed0.npz.
# Text(0.5, 1.0, 'neff vs Bend Radius: TE (SOI)')

# %%
te_wvg = gt.modes.Waveguide(
    wavelength=1550 * nm, 
    core_width=500*nm,       
    slab_thickness=0.0,
    core_material='si',
    clad_material='sio2',
    core_thickness=220 * nm,
    num_modes=1,
    cache_path='.cache/',
    precision='double',
    max_grid_scaling=1.3,
    grid_resolution=50, 
)



mismatch_loss = gt.modes.sweep_bend_mismatch(te_wvg, bend_radius)
mismatch_loss_dB = -10 * np.log10(mismatch_loss) 
dB_cm = 1.5 
length_cm = 0.5 * np.pi * bend_radius * 1e-4
prop_loss_dB = dB_cm * length_cm
total_loss_dB = mismatch_loss_dB + prop_loss_dB

plt.figure(figsize=(8,5))
plt.title("Loss TE SOI")
plt.plot(bend_radius, mismatch_loss_dB, "o-", label="Mode mismatch loss")
plt.plot(bend_radius, prop_loss_dB, "o-", label="Propagation loss")
plt.plot(bend_radius, total_loss_dB, "o-", label="Total loss")
plt.xlabel("Bend radius (um)")
plt.ylabel("Loss (dB/90º)")
plt.grid()
plt.legend()
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# c:\Users\María Romero García\Documents\UNI\PIC MÁSTER\diseño\lab 1\pic-upv-lab1\.venv\Lib\site-packages\tidy3d\components\mode\derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))

# %% [markdown]
# ## Grading
#
# LO.1. 2 Point <br>
# LO.2. 1 Points <br>
# LO.3. 3 Point <br>
# LO.4. 1 Points <br>
# **Total 7 Points** <br>
# Extra (Up to) 3 Points
